# %%
dbutils.widgets.text("RUTA_ARCHIVO_TABLAS", "/mnt/agpacmr/CATALOGOS/Fuenetes_mvp.csv", "1.- Ruta de archivo con catalogo de tablas")
print(dbutils.widgets.get("RUTA_ARCHIVO_TABLAS"))
print('hehiehihei')
